# %%
# importing the dataset for birth rates in Europe

import pandas as pd
from matplotlib import pyplot as plt

Birth_rate = pd.read_csv("/content/drive/MyDrive/birth_rates.csv")
print(Birth_rate)
# Out:
#                  DATAFLOW        LAST UPDATE freq  indic_de geo  TIME_PERIOD  \
# 0    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2017
# 1    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2018
# 2    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2020
# 3    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2021
# 4    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AM         2017
# ..                    ...                ...  ...       ...  ..          ...
# 192  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  UK         2017
# 193  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  UK         2018
# 194  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  XK         2017
# 195  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  XK         2018
# 196  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  XK         2019
#
#      OBS_VALUE OBS_FLAG
# ...

# %%
Birth_rate
# Out:
#                  DATAFLOW        LAST UPDATE freq  indic_de geo  TIME_PERIOD  \
# 0    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2017
# 1    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2018
# 2    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2020
# 3    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2021
# 4    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AM         2017
# ..                    ...                ...  ...       ...  ..          ...
# 192  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  UK         2017
# 193  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  UK         2018
# 194  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  XK         2017
# 195  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  XK         2018
# 196  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  XK         2019
#
#      OBS_VALUE OBS_FLAG
# ...

# %%
Birth_rate.columns
# Out:
# Index(['DATAFLOW', 'LAST UPDATE', 'freq', 'indic_de', 'geo', 'TIME_PERIOD',
#        'OBS_VALUE', 'OBS_FLAG'],
#       dtype='object')

# %%
shape = Birth_rate.shape
shape
# Out:
# (197, 8)

# %%
info = Birth_rate.info()
info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATAFLOW     197 non-null    object
#  1   LAST UPDATE  197 non-null    object
#  2   freq         197 non-null    object
#  3   indic_de     197 non-null    object
#  4   geo          197 non-null    object
#  5   TIME_PERIOD  197 non-null    int64
#  6   OBS_VALUE    197 non-null    float64
#  7   OBS_FLAG     19 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 12.4+ KB

# %%
Birth_rate.describe()
# Out:
#        TIME_PERIOD   OBS_VALUE
# count   197.000000  197.000000
# mean   2018.883249    1.552843
# std       1.407550    0.190333
# min    2017.000000    1.130000
# 25%    2018.000000    1.430000
# 50%    2019.000000    1.560000
# 75%    2020.000000    1.680000
# max    2021.000000    2.140000

# %%
x = Birth_rate['OBS_VALUE'].mean()
print("The mean birth rate in Europe is :", x)
# Out:
# The mean birth rate in Europe is : 1.552842639593909

# %%
Birth_rate.sort_values('OBS_VALUE')
# Out:
#                  DATAFLOW        LAST UPDATE freq  indic_de geo  TIME_PERIOD  \
# 139  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  MT         2020
# 140  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  MT         2021
# 191  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  UA         2019
# 138  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  MT         2019
# 65   ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  ES         2020
# ..                    ...                ...  ...       ...  ..          ...
# 187  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  TR         2018
# 79   ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  GE         2019
# 186  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  TR         2017
# 78   ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  GE         2018
# 77   ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  GE         2017
#
#      OBS_VALUE OBS_FLAG
# ...

# %%
Birth_rate.sort_values('OBS_VALUE', ascending = False)
# Out:
#                  DATAFLOW        LAST UPDATE freq  indic_de geo  TIME_PERIOD  \
# 77   ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  GE         2017
# 78   ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  GE         2018
# 186  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  TR         2017
# 79   ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  GE         2019
# 187  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  TR         2018
# ..                    ...                ...  ...       ...  ..          ...
# 65   ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  ES         2020
# 138  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  MT         2019
# 191  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  UA         2019
# 139  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  MT         2020
# 140  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  MT         2021
#
#      OBS_VALUE OBS_FLAG
# ...

# %%
# plotting a line graph that shows all birth rates from 2017 to 2021 grouped by countries
Birth_rate.plot(figsize=(16,4),x='geo',y='OBS_VALUE')
plt.title('Birth rates in Europe 2017-2021')
plt.ylabel('Birth rate')
plt.xlabel('Countries')
plt.grid()

# %%
df2 = Birth_rate.loc[Birth_rate['geo'] == 'RO']
df2
# Out:
#                  DATAFLOW        LAST UPDATE freq  indic_de geo  TIME_PERIOD  \
# 161  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  RO         2017
# 162  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  RO         2018
# 163  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  RO         2019
# 164  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  RO         2020
# 165  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  RO         2021
#
#      OBS_VALUE OBS_FLAG
# 161       1.78      NaN
# 162       1.76      NaN
# 163       1.77        e
# 164       1.80        e
# 165       1.81        e

# %%
# changing the time period values from floating numbers to strings
df1 = Birth_rate['TIME_PERIOD'].astype(str)

# %%
# plotting a line graph that shows birth rates only in Romania from 2017 to 2021
plt.plot(df2['TIME_PERIOD'].astype(str),df2['OBS_VALUE'])
plt.plot(figsize=(12,6))
plt.title('Birth rates in Romania 2017-2021')
plt.ylabel('Birth rate')
plt.xlabel('Years')
plt.grid()

# %%
# creating a new dataset with only the counties, years and birth rates
nd = Birth_rate[['geo','TIME_PERIOD','OBS_VALUE']]
nd
# Out:
#     geo  TIME_PERIOD  OBS_VALUE
# 0    AL         2017       1.48
# 1    AL         2018       1.37
# 2    AL         2020       1.34
# 3    AL         2021       1.31
# 4    AM         2017       1.56
# ..   ..          ...        ...
# 192  UK         2017       1.74
# 193  UK         2018       1.68
# 194  XK         2017       1.65
# 195  XK         2018       1.61
# 196  XK         2019       1.55
#
# [197 rows x 3 columns]

# %%
# selecting only the data relevant for 2019 and 2020
Y2019 = nd.loc[nd['TIME_PERIOD'] == 2019]
Y2020 = nd.loc[nd['TIME_PERIOD'] == 2020]
print(Y2019,Y2020)
# Out:
#     geo  TIME_PERIOD  OBS_VALUE
# 6    AM         2019       1.60
# 9    AT         2019       1.46
# 14   AZ         2019       1.81
# 17   BE         2019       1.60
# 22   BG         2019       1.58
# 29   CH         2019       1.48
# 34   CY         2019       1.33
# 39   CZ         2019       1.71
# 44   DE         2019       1.54
# 49   DK         2019       1.70
# 54   EE         2019       1.66
# 59   EL         2019       1.34
# 64   ES         2019       1.23
# 69   FI         2019       1.35
# 74   FR         2019       1.86
# 79   GE         2019       2.02
# 83   HR         2019       1.47
# 88   HU         2019       1.55
# 93   IE         2019       1.71
# 98   IS         2019       1.74
# 103  IT         2019       1.27
# 108  LI         2019       1.48
# 113  LT         2019       1.61
# 118  LU         2019       1.34
# 123  LV         2019       1.61
# 128  ME         2019       1.77
# 133  MK         2019       1.34
# 138  MT         2019       1.14
# ...

# %%
# determining the countries present in both years
EU_countries = pd.Index(Y2019.geo).intersection(pd.Index(Y2020.geo))
EU_countries
# Out:
# Index(['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI',
#        'FR', 'GE', 'HR', 'HU', 'IE', 'IS', 'IT', 'LI', 'LT', 'LU', 'LV', 'ME',
#        'MK', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'RS', 'SE', 'SI', 'SK'],
#       dtype='object', name='geo')

# %%
# creating a list with those countires
EU_countries_list = list(EU_countries)
EU_countries_list
# Out:
# ['AT',
#  'BE',
#  'BG',
#  'CH',
#  'CY',
#  'CZ',
#  'DE',
#  'DK',
#  'EE',
#  'EL',
#  'ES',
#  'FI',
#  'FR',
#  'GE',
#  'HR',
#  'HU',
#  'IE',
#  'IS',
#  'IT',
#  'LI',
#  'LT',
#  'LU',
#  'LV',
#  'ME',
#  'MK',
#  'MT',
#  'NL',
#  'NO',
#  'PL',
#  'PT',
#  'RO',
#  'RS',
#  'SE',
#  'SI',
#  'SK']

# %%
# creating a dataset to compare the birth rates of countries in 2019 and 2020

Data2019 = Y2019.loc[Y2019['geo'].str.contains('|'.join(EU_countries_list))]
Data2020 = Y2020.loc[Y2020['geo'].str.contains('|'.join(EU_countries_list))]

data = {'Country':EU_countries_list,'2019':list(Data2019.OBS_VALUE),'2020':list(Data2020.OBS_VALUE)}
mean_values = pd.DataFrame(data)
mean_values
# Out:
#    Country  2019  2020
# 0       AT  1.46  1.44
# 1       BE  1.60  1.55
# 2       BG  1.58  1.56
# 3       CH  1.48  1.46
# 4       CY  1.33  1.36
# 5       CZ  1.71  1.74
# 6       DE  1.54  1.53
# 7       DK  1.70  1.68
# 8       EE  1.66  1.58
# 9       EL  1.34  1.39
# 10      ES  1.23  1.19
# 11      FI  1.35  1.37
# 12      FR  1.86  1.83
# 13      GE  2.02  1.98
# 14      HR  1.47  1.48
# 15      HU  1.55  1.59
# 16      IE  1.71  1.63
# 17      IS  1.74  1.72
# 18      IT  1.27  1.24
# 19      LI  1.48  1.46
# 20      LT  1.61  1.48
# 21      LU  1.34  1.36
# 22      LV  1.61  1.55
# 23      ME  1.77  1.75
# 24      MK  1.34  1.31
# 25      MT  1.14  1.13
# 26      NL  1.57  1.54
# 27      NO  1.53  1.48
# 28      PL  1.44  1.39
# 29      PT  1.43  1.41
# 30      RO  1.77  1.80
# 31      RS  1.52  1.48
# 32      SE  1.71  1.67
# 33      SI  1.61  1.59
# 34      SK  1.57  1.59

# %%
# plotting a bar chart for better visualization

mean_values.plot(figsize=(12,6),x='Country', y=['2019','2020'],kind='bar')

plt.title("Birth Rates EU (2019-2020)")
plt.xlabel("Year")
plt.ylabel("Birth Rate")
plt.show()

# %%
# creating a dataset with Romania and its neighbouring countries

countries_of_interest = ['RO','MD','BG','RS','HU','UA']

InterestData2019 = Y2019.loc[Y2019['geo'].str.contains('|'.join(countries_of_interest))]
InterestData2020 = Y2020.loc[Y2020['geo'].str.contains('|'.join(countries_of_interest))]
print(InterestData2019, InterestData2020)
# Out:
#     geo  TIME_PERIOD  OBS_VALUE
# 22   BG         2019       1.58
# 88   HU         2019       1.55
# 163  RO         2019       1.77
# 168  RS         2019       1.52
# 191  UA         2019       1.14     geo  TIME_PERIOD  OBS_VALUE
# 23   BG         2020       1.56
# 89   HU         2020       1.59
# 164  RO         2020       1.80
# 169  RS         2020       1.48

# %%
# eliminating countries which do not have data for both years
Neighbouring_countries = pd.Index(InterestData2019.geo).intersection(pd.Index(InterestData2020.geo))
Neighbouring_countries
# Out:
# Index(['BG', 'HU', 'RO', 'RS'], dtype='object', name='geo')

# %%
# creating a table to compare Romania's birth rates with those of its neighbouring countries

Interest_Data_2019 = Y2019.loc[Y2019['geo'].str.contains('|'.join(Neighbouring_countries))]
Interest_Data_2020 = Y2020.loc[Y2020['geo'].str.contains('|'.join(Neighbouring_countries))]

data = {'Country':Neighbouring_countries,'2019':list(Interest_Data_2019.OBS_VALUE),'2020':list(Interest_Data_2020.OBS_VALUE)}
mean_values = pd.DataFrame(data)
mean_values
# Out:
#   Country  2019  2020
# 0      BG  1.58  1.56
# 1      HU  1.55  1.59
# 2      RO  1.77  1.80
# 3      RS  1.52  1.48

# %%
# plotting a bar chart for better visualization

mean_values.plot(figsize=(10,4),x='Country', y=['2019','2020'],kind='bar')

plt.title("Birth Rates Neighbouring Countries (2019-2020")
plt.xlabel("Year")
plt.ylabel("Birth Rate")
plt.show()

# %%
# determining the mean birth rate on a specific year

def getYearlyData(year):
    return Birth_rate.loc[Birth_rate['TIME_PERIOD']==year]['OBS_VALUE'].mean()

All_Years = list(set(Birth_rate.TIME_PERIOD))

Year_Mean_Birth_Rates = list(map(getYearlyData,All_Years))
Year_Mean_Birth_Rates
# Out:
# [1.5830232558139536,
#  1.5651162790697677,
#  1.5505,
#  1.5180555555555557,
#  1.5391428571428574]

# %%
# creating a new dataset that groups the year and mean of birth rates

YearlyMeanDataset = {'Year': All_Years,'Mean of Birth Rates':Year_Mean_Birth_Rates}
YearlyDataFrame = pd.DataFrame(YearlyMeanDataset)
YearlyDataFrame
# Out:
#    Year  Mean of Birth Rates
# 0  2017             1.583023
# 1  2018             1.565116
# 2  2019             1.550500
# 3  2020             1.518056
# 4  2021             1.539143

# %%
# plotting a graph for better visualization

print(YearlyDataFrame.plot(x='Year',y='Mean of Birth Rates',kind='line'))
plt.grid()
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
# importing the dataset for GDP per capita in Europe

import pandas as pd
from matplotlib import pyplot as plt

GDP_per_capita = pd.read_csv("/content/drive/MyDrive/gdp_europe.csv")
print(GDP_per_capita)
# Out:
#                   DATAFLOW        LAST UPDATE freq        unit na_item geo  \
# 0    ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# 1    ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# 2    ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# 3    ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# 4    ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# ..                     ...                ...  ...         ...     ...  ..
# 177  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  TR
# 178  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  TR
# 179  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  UK
# 180  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  UK
# 181  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  UK
#
#      TIME_PERIOD  OBS_VALUE OBS_FLAG
# ...

# %%
GDP_per_capita.describe()
# Out:
#        TIME_PERIOD      OBS_VALUE
# count   182.000000     182.000000
# mean   2018.972527   34387.087912
# std       1.411990   29975.873388
# min    2017.000000    4020.000000
# 25%    2018.000000   14297.500000
# 50%    2019.000000   24780.000000
# 75%    2020.000000   44875.000000
# max    2021.000000  164150.000000

# %%
# plotting a line graph that shows GDP per capita from 2017 to 2021 grouped by countries

GDP_per_capita.plot(figsize=(16,4),x='geo',y='OBS_VALUE')
plt.title('GDP per capita in Europe 2017-2021')
plt.ylabel('GDP')
plt.xlabel('Countries')
plt.grid()

# %%
print(Birth_rate, GDP_per_capita)
# Out:
#                  DATAFLOW        LAST UPDATE freq  indic_de geo  TIME_PERIOD  \
# 0    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2017
# 1    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2018
# 2    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2020
# 3    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2021
# 4    ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AM         2017
# ..                    ...                ...  ...       ...  ..          ...
# 192  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  UK         2017
# 193  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  UK         2018
# 194  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  XK         2017
# 195  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  XK         2018
# 196  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  XK         2019
#
#      OBS_VALUE OBS_FLAG
# ...

# %%
Birth_rate.head()
# Out:
#                DATAFLOW        LAST UPDATE freq  indic_de geo  TIME_PERIOD  \
# 0  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2017
# 1  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2018
# 2  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2020
# 3  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AL         2021
# 4  ESTAT:DEMO_FIND(1.0)  21/12/23 23:00:00    A  TOTFERRT  AM         2017
#
#    OBS_VALUE OBS_FLAG
# 0       1.48      NaN
# 1       1.37      NaN
# 2       1.34      NaN
# 3       1.31      NaN
# 4       1.56      NaN

# %%
GDP_per_capita.head()
# Out:
#                 DATAFLOW        LAST UPDATE freq        unit na_item geo  \
# 0  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# 1  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# 2  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# 3  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# 4  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
#
#    TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0         2017       4020      NaN
# 1         2018       4480      NaN
# 2         2019       4820      NaN
# 3         2020       4690      NaN
# 4         2021       5390        p

# %%
# renaming the column OBS_VALUE so it does not overlap on the 2 datasets

GDP_per_capita.rename(columns = {'OBS_VALUE':'GDP'}, inplace = True)
GDP_per_capita
# Out:
#                   DATAFLOW        LAST UPDATE freq        unit na_item geo  \
# 0    ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# 1    ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# 2    ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# 3    ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# 4    ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  AL
# ..                     ...                ...  ...         ...     ...  ..
# 177  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  TR
# 178  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  TR
# 179  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  UK
# 180  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  UK
# 181  ESTAT:NAMA_10_PC(1.0)  19/01/24 23:00:00    A  CP_EUR_HAB    B1GQ  UK
#
#      TIME_PERIOD    GDP OBS_FLAG
# 0           2017   4020      NaN
# ...

# %%
Birth_rate.shape
# Out:
# (197, 8)

# %%
GDP_per_capita.shape
# Out:
# (182, 9)

# %%
Births = pd.DataFrame(Birth_rate,columns = ['geo','TIME_PERIOD','OBS_VALUE'])

print(Births)
print(Births.dtypes)
# Out:
#     geo  TIME_PERIOD  OBS_VALUE
# 0    AL         2017       1.48
# 1    AL         2018       1.37
# 2    AL         2020       1.34
# 3    AL         2021       1.31
# 4    AM         2017       1.56
# ..   ..          ...        ...
# 192  UK         2017       1.74
# 193  UK         2018       1.68
# 194  XK         2017       1.65
# 195  XK         2018       1.61
# 196  XK         2019       1.55
#
# [197 rows x 3 columns]
# geo             object
# TIME_PERIOD      int64
# OBS_VALUE      float64
# dtype: object

# %%
# changing the "OBS_VALUE" in the birth rates dataset from floating to integer -> needed for merging the 2 datasets

Births['OBS_VALUE'] = Births['OBS_VALUE'].multiply(100).astype(int)
Births['TIME_PERIOD'] = Births['TIME_PERIOD'].astype(str)
Births
# Out:
#     geo TIME_PERIOD  OBS_VALUE
# 0    AL        2017        148
# 1    AL        2018        137
# 2    AL        2020        134
# 3    AL        2021        131
# 4    AM        2017        156
# ..   ..         ...        ...
# 192  UK        2017        174
# 193  UK        2018        168
# 194  XK        2017        165
# 195  XK        2018        161
# 196  XK        2019        155
#
# [197 rows x 3 columns]

# %%
# merging specific columns from the 2 datasets

df_merged = Births.merge(GDP_per_capita[['geo', 'GDP']])
print(df_merged)
# Out:
#     geo TIME_PERIOD  OBS_VALUE    GDP
# 0    AL        2017        148   4020
# 1    AL        2017        148   4480
# 2    AL        2017        148   4820
# 3    AL        2017        148   4690
# 4    AL        2017        148   5390
# ..   ..         ...        ...    ...
# 881  UK        2017        174  36440
# 882  UK        2017        174  37830
# 883  UK        2018        168  35730
# 884  UK        2018        168  36440
# 885  UK        2018        168  37830
#
# [886 rows x 4 columns]

# %%
# finding the correlation between Births and GDP

df_merged['OBS_VALUE'].corr(df_merged['GDP'])
# Out:
# -0.003077507814769421

# %%
# creating a heat map to see the correlation matrix

import seaborn as sns
sns.heatmap(df_merged.corr(),annot = True)
# Out:
# <ipython-input-107-d961a74642d8>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_merged.corr(),annot = True)
# <Axes: >

# %%
# plotting a data distribution for Births

plt.title('Birth Distribution Plot')
sns.distplot(df_merged['OBS_VALUE'])
plt.show()
# Out:
# <ipython-input-108-70902f9d0689>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_merged['OBS_VALUE'])

# %%
# plotting a scatter graph to see the relationship between Births and GDP per capita

plt.scatter(df_merged['OBS_VALUE'], df_merged['GDP'], color = 'lightcoral')
plt.title('Births vs GDP per capita')
plt.xlabel('Births')
plt.ylabel('GDP per capita')
plt.box(False)
plt.show()

# %%
# making a table only with the birth rates and GDP per capita from the merged dataset

linear = df_merged[['OBS_VALUE', 'GDP']]
linear
# Out:
#      OBS_VALUE    GDP
# 0          148   4020
# 1          148   4480
# 2          148   4820
# 3          148   4690
# 4          148   5390
# ..         ...    ...
# 881        174  36440
# 882        174  37830
# 883        168  35730
# 884        168  36440
# 885        168  37830
#
# [886 rows x 2 columns]

# %%
# creating x and y variables

x = df_merged['GDP'] #independent
y = df_merged['OBS_VALUE'] #dependent

# %%
linear_new = pd.DataFrame({'X': x, 'Y': y})
linear_new.head()
# Out:
#       X    Y
# 0  4020  148
# 1  4480  148
# 2  4820  148
# 3  4690  148
# 4  5390  148

# %%
# plotting the data and getting a current axis of the scatter graph

import numpy as np
fig = plt.figure(figsize=(15,7))
ax = plt.gca()
ax.scatter(x, y, c ='k')
ax.plot((linear_new['X'].min(), linear_new['X'].max()),(np.mean(linear_new['Y']), np.mean(linear_new['Y'])), color='r');

# %%
# finding the value that interceps with the y axis

linear_new['MeanY'] = linear_new['Y'].mean()
linear_new.head()
# Out:
#       X    Y       MeanY
# 0  4020  148  154.325056
# 1  4480  148  154.325056
# 2  4820  148  154.325056
# 3  4690  148  154.325056
# 4  5390  148  154.325056

# %%
# calculating the SSE - how much variation in y is left unexplained by the model

np.sum(np.square(linear_new['Y'] - linear_new['MeanY']))
# Out:
# 273590.3837471783

# %%
# calculating the MSE - how close a regression line is to a set of data points

np.mean(np.square(linear_new['Y'] - linear_new['MeanY']))
# Out:
# 308.7927581796595

# %%
# calculating the RMSE - the average difference between values predicted by a model and the actual values

(np.mean(np.square(linear_new['Y'] - linear_new['MeanY']))) ** 0.5
# Out:
# 17.57250005490566

# %%
# calculating the beta coefficients by hand

y_bar = linear_new['Y'].mean()
x_bar = linear_new['X'].mean()
std_y = np.std(linear_new['Y'], ddof = 1)
std_x = np.std(linear_new['X'], ddof = 1)
r_xy = linear_new.corr().loc['X','Y']
beta_1 = r_xy*(std_y/std_x)
beta_0 = y_bar - beta_1*x_bar

linear_new['Linear_Y'] = beta_0 + beta_1 * linear_new['X']

np.square(linear_new['Y'] - linear_new['Linear_Y']).mean()
# Out:
# 308.7898335866639

# %%
# re-plotting the regression line

fig = plt.figure(figsize=(15,7))
ax = plt.gca()
ax.scatter(x, y, c='k')
ax.plot(linear_new['X'], linear_new['Linear_Y'], color='r');

# %%
# plotting the residuals

fig = plt.figure(figsize=(15,7))
fig.set_figheight(8)
fig.set_figwidth(15)
ax = fig.gca()
ax.scatter(x=linear_new['X'], y=linear_new['Y'], c='k')
ax.plot(linear_new['X'], linear_new['Linear_Y'], color='k');
for _, row in linear_new.iterrows():
    plt.plot((row['X'], row['X']), (row['Y'], row['Linear_Y']), 'r-')
